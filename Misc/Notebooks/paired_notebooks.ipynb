# %% [markdown]
# # Paired notebooks

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(0.1, 3.0, 101)
y = np.log(x)

# %%
_ = plt.plot(x, y)

# %%
y = np.sqrt(x)

# %%
_ = plt.plot(x, y)
_ = plt.xlabel('x')
_ = plt.ylabel('y')
