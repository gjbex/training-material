# %% [markdown]
# # Topological sort

# %% [markdown]
# Load the required libraries, and set matplotlib output.

# %%
import networkx as nx
from topo_sort import show_sorted, create_graph, create_refs
import matplotlib.pyplot as plt
# %matplotlib  inline

# %% [markdown]
# Show the references.

# %%
print('\n'.join(n.format() for n in create_refs().values()))
# Out:
# [E02] Eve "Hacking blowfish", Hacker magazine, 2002
# [C03] Carol "Pufferfish: a new encryption algorithm", Notices of the Luxemburg Academy of Sciences, 2003
# [T04] Trent "Review of modern encryption systems", ACM Research on Security, 2004
# [B02b] Bob "Applying blowfish for email encryption", Security research, 2002
# [A03] Alice "Proving blowfish to be mathemattically secure", Security research, 2003
# [B02a] Bob "Applying blowfish for fun and profit", Security research, 2002
# [A01] Alice "Encryption with blowfish", Security research, 2001

# %% [markdown]
# Create the directed graph representing citations of publications.

# %%
G = create_graph()

# %% [markdown]
# Show the resulting graph.

# %%
nx.draw_networkx(G, with_labels=True)

# %% [markdown]
# Compute the topological sort, and print references.

# %%
show_sorted(G)
# Out:
# [A01] Alice "Encryption with blowfish", Security research, 2001
# [B02a] Bob "Applying blowfish for fun and profit", Security research, 2002
# [B02b] Bob "Applying blowfish for email encryption", Security research, 2002
# [E02] Eve "Hacking blowfish", Hacker magazine, 2002
# [T04] Trent "Review of modern encryption systems", ACM Research on Security, 2004
# [C03] Carol "Pufferfish: a new encryption algorithm", Notices of the Luxemburg Academy of Sciences, 2003
# [A03] Alice "Proving blowfish to be mathemattically secure", Security research, 2003
